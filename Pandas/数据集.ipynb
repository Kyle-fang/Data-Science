# %% [markdown]
# ### 导入包

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 读入数据

# %%
df = pd.read_excel('data/city.xls')
df.head()
# Out:
#      地区     2018年     2017年     2016年     2015年     2014年
# 0    北京  30319.98  28014.94  25669.13  23014.59  21330.83
# 1    天津  18809.64  18549.19  17885.39  16538.19  15726.93
# 2   石家庄       NaN   6460.88   5927.73   5440.60   5170.27
# 3    太原       NaN   3382.18   2955.60   2735.34   2531.09
# 4  呼和浩特       NaN   2743.72   3173.59   3090.52   2894.05

# %% [markdown]
# # 数据重塑和轴向旋转

# %% [markdown]
# ## (1)层次化索引

# %% [markdown]
# ### &emsp;&emsp;Series的层次化索引

# %%
s = pd.Series(np.arange(1,10),index=[['a','a','a','b','b','b','c','c','c'],[1,2,3,1,2,3,1,2,3]])

# %%
s.index
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 2),
#             ('b', 3),
#             ('c', 1),
#             ('c', 2),
#             ('c', 3)],
#            )

# %%
s['a']
# Out:
# 1    1
# 2    2
# 3    3
# dtype: int32

# %%
#切片
s['a':'c']
# Out:
# a  1    1
#    2    2
#    3    3
# b  1    4
#    2    5
#    3    6
# c  1    7
#    2    8
#    3    9
# dtype: int32

# %%
#内层选取
s[:,2]
# Out:
# a    2
# b    5
# c    8
# dtype: int32

# %%
s['c',3]
# Out:
# 9

# %% [markdown]
# #### 通过unstack方法可以将Series变成一个DataFrame

# %%
s.unstack()
# Out:
#    1  2  3
# a  1  2  3
# b  4  5  6
# c  7  8  9

# %% [markdown]
# ### &emsp;&emsp;DataFrame的层次化索引

# %% [markdown]
# 对于DataFrame来说,行和列都能进行层次化索引

# %%
data = pd.DataFrame(np.arange(12).reshape(4,3))

# %%
data
# Out:
#    0   1   2
# 0  0   1   2
# 1  3   4   5
# 2  6   7   8
# 3  9  10  11

# %%
data = pd.DataFrame(np.arange(12).reshape(4,3),index=[['a','a','b','b'],[1,2,1,2]],columns=[['A','A','B'],['Z','X','C']])
data
# Out:
#      A       B
#      Z   X   C
# a 1  0   1   2
#   2  3   4   5
# b 1  6   7   8
#   2  9  10  11

# %%
data['A']
# Out:
#      Z   X
# a 1  0   1
#   2  3   4
# b 1  6   7
#   2  9  10

# %%
data['B']
# Out:
#       C
# a 1   2
#   2   5
# b 1   8
#   2  11

# %%
data.index.names=['row1','row2']
data.columns.names=['col1','col2']
data
# Out:
# col1       A       B
# col2       Z   X   C
# row1 row2
# a    1     0   1   2
#      2     3   4   5
# b    1     6   7   8
#      2     9  10  11

# %%
data.swaplevel('row1','row2')
# Out:
# col1       A       B
# col2       Z   X   C
# row2 row1
# 1    a     0   1   2
# 2    a     3   4   5
# 1    b     6   7   8
# 2    b     9  10  11

# %% [markdown]
# ### 可将城市GDP数据也处理成一种多层索引的结构

# %%
df.index
# Out:
# RangeIndex(start=0, stop=37, step=1)

# %% [markdown]
# #### 将地区设置为外层索引,年份设置为内层索引
#    - set_index可将列变成索引
#    - reset_index是将索引变成列

# %%
df = df.set_index('地区')
df
# Out:
#                2018年     2017年     2016年     2015年     2014年
# 地区
# 北京          30319.98  28014.94  25669.13  23014.59  21330.83
# 天津          18809.64  18549.19  17885.39  16538.19  15726.93
# 石家庄              NaN   6460.88   5927.73   5440.60   5170.27
# 太原               NaN   3382.18   2955.60   2735.34   2531.09
# 呼和浩特             NaN   2743.72   3173.59   3090.52   2894.05
# 沈阳               NaN   5864.97   5460.01   7272.31   7098.71
# 大连               NaN   7363.92   6730.33   7731.64   7655.58
# 长春               NaN   6530.03   5917.94   5530.03   5342.43
# 哈尔滨              NaN   6355.05   6101.61   5751.21   5340.07
# 上海          32679.87  30632.99  28178.65  25123.45  23567.70
# 南京               NaN  11715.10  10503.02   9720.77   8820.75
# 杭州               NaN  12603.36  11313.72  10050.21   9206.16
# 宁波               NaN   9842.10   8686.49   8003.61   7610.28
# 合肥               NaN   7213.45   6274.38   5660.27   5157.97
# 福州               NaN   7103.40   6197.64   5618.08   5169.16
# 厦门               NaN   4351.70   3784.27   3466.03   3273.58
# 南昌               NaN   5003.19   4354.99   4000.01   3667.96
# 济南               NaN   7201.96   6536.12   6100.23   5770.60
# 青岛               NaN  11037.28  10011.29   9300.07   8692.10
# 郑州               NaN   9130.20   8025.31   7311.52   6776.99
# 武汉               NaN  13410.34  11912.61  10905.60  10069.48
# 长沙               NaN  10535.51   9455.36   8510.13   7824.81
# 广州               NaN  21503.15  19547.44  18100.41  16706.87
# 深圳               NaN  22490.06  19492.60  17502.86  16001.82
# 南宁               NaN   4118.83   3703.39   3410.09   3148.30
# 海口               NaN   1390.58   1257.67   1161.96   1091.70
# 重庆          20363.19  19424.73  17740.59  15717.27  14262.60
# 成都               NaN  13889.39  12170.23  10801.16  10056.59
# 贵阳               NaN   3537.96   3157.70   2891.16   2497.27
# 昆明               NaN   4857.64   4300.08   3968.01   3712.99
# 拉萨               NaN    479.25    424.95    376.73    347.45
# 西安               NaN   7469.85   6257.18   5801.20   5492.64
# 兰州               NaN   2523.54   2264.23   2095.99   2000.94
# 西宁               NaN   1284.91   1248.17   1131.62   1065.78
# 银川               NaN   1803.26   1617.71   1493.86   1388.62
# 乌鲁木齐             NaN   2743.82   2458.98   2631.64   2461.47
# 数据来源：国家统计局       NaN       NaN       NaN       NaN       NaN

# %% [markdown]
# ### 取消层次化索引

# %%
df = df.reset_index()

# %%
df[:5]
# Out:
#      地区     2018年     2017年     2016年     2015年     2014年
# 0    北京  30319.98  28014.94  25669.13  23014.59  21330.83
# 1    天津  18809.64  18549.19  17885.39  16538.19  15726.93
# 2   石家庄       NaN   6460.88   5927.73   5440.60   5170.27
# 3    太原       NaN   3382.18   2955.60   2735.34   2531.09
# 4  呼和浩特       NaN   2743.72   3173.59   3090.52   2894.05

# %% [markdown]
# ## (2)数据旋转

# %%
data = df[:5]
data
# Out:
#      地区     2018年     2017年     2016年     2015年     2014年
# 0    北京  30319.98  28014.94  25669.13  23014.59  21330.83
# 1    天津  18809.64  18549.19  17885.39  16538.19  15726.93
# 2   石家庄       NaN   6460.88   5927.73   5440.60   5170.27
# 3    太原       NaN   3382.18   2955.60   2735.34   2531.09
# 4  呼和浩特       NaN   2743.72   3173.59   3090.52   2894.05

# %% [markdown]
# #### 直接让数据的行列进行交换

# %%
data.T
# Out:
#              0        1        2        3        4
# 地区          北京       天津      石家庄       太原     呼和浩特
# 2018年    30320  18809.6      NaN      NaN      NaN
# 2017年  28014.9  18549.2  6460.88  3382.18  2743.72
# 2016年  25669.1  17885.4  5927.73   2955.6  3173.59
# 2015年  23014.6  16538.2   5440.6  2735.34  3090.52
# 2014年  21330.8  15726.9  5170.27  2531.09  2894.05

# %% [markdown]
# ### DataFrame也可以使用stack和unstack,转化为层次化索引的Series

# %%
data.stack()
# Out:
# 0  地区            北京
#    2018年      30320
#    2017年    28014.9
#    2016年    25669.1
#    2015年    23014.6
#    2014年    21330.8
# 1  地区            天津
#    2018年    18809.6
#    2017年    18549.2
#    2016年    17885.4
#    2015年    16538.2
#    2014年    15726.9
# 2  地区           石家庄
#    2017年    6460.88
#    2016年    5927.73
#    2015年     5440.6
#    2014年    5170.27
# 3  地区            太原
#    2017年    3382.18
#    2016年     2955.6
#    2015年    2735.34
#    2014年    2531.09
# 4  地区          呼和浩特
#    2017年    2743.72
#    2016年    3173.59
#    2015年    3090.52
#    2014年    2894.05
# dtype: object

# %%
data.unstack()
# Out:
# 地区     0         北京
#        1         天津
#        2        石家庄
#        3         太原
#        4       呼和浩特
# 2018年  0      30320
#        1    18809.6
#        2        NaN
#        3        NaN
#        4        NaN
# 2017年  0    28014.9
#        1    18549.2
#        2    6460.88
#        3    3382.18
#        4    2743.72
# 2016年  0    25669.1
#        1    17885.4
#        2    5927.73
#        3     2955.6
#        4    3173.59
# 2015年  0    23014.6
#        1    16538.2
#        2     5440.6
#        3    2735.34
#        4    3090.52
# 2014年  0    21330.8
#        1    15726.9
#        2    5170.27
#        3    2531.09
#        4    2894.05
# dtype: object

# %% [markdown]
# ## (3)数据分组，分组运算

# %% [markdown]
# #### - GroupBy技术：实现数据的分组，分组运算，作用类似于数据透视表

# %%
group = df.groupby(df['地区'])

# %%
type(group)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# #### 可以计算分组后的各个统计量
#    - 只会对数值变量进行分组运算

# %%
group.mean().head()
# Out:
#          2018年     2017年     2016年     2015年     2014年
# 地区
# 上海    32679.87  30632.99  28178.65  25123.45  23567.70
# 乌鲁木齐       NaN   2743.82   2458.98   2631.64   2461.47
# 兰州         NaN   2523.54   2264.23   2095.99   2000.94
# 北京    30319.98  28014.94  25669.13  23014.59  21330.83
# 南京         NaN  11715.10  10503.02   9720.77   8820.75

# %% [markdown]
# ## 离散化处理
# - 离散化也称为分组，区间化，Pandas为我们提供了方便的函数cut()
# - pd.cut(x, bins, right=True, labels=None, retbins=False, precision=3, include_lowest=False):
#    - x：需要离散化的数组，Series，DataFrame对象
#    - bins：分组的依据

# %%
df['GDP等级'] = pd.cut(df['2017年'],[0, 4000, 10000, 20000, 30000,35000],labels=['E','D','C','B','A'])
df
# Out:
#             地区     2018年     2017年     2016年     2015年     2014年 GDP等级
# 0           北京  30319.98  28014.94  25669.13  23014.59  21330.83     B
# 1           天津  18809.64  18549.19  17885.39  16538.19  15726.93     C
# 2          石家庄       NaN   6460.88   5927.73   5440.60   5170.27     D
# 3           太原       NaN   3382.18   2955.60   2735.34   2531.09     E
# 4         呼和浩特       NaN   2743.72   3173.59   3090.52   2894.05     E
# 5           沈阳       NaN   5864.97   5460.01   7272.31   7098.71     D
# 6           大连       NaN   7363.92   6730.33   7731.64   7655.58     D
# 7           长春       NaN   6530.03   5917.94   5530.03   5342.43     D
# 8          哈尔滨       NaN   6355.05   6101.61   5751.21   5340.07     D
# 9           上海  32679.87  30632.99  28178.65  25123.45  23567.70     A
# 10          南京       NaN  11715.10  10503.02   9720.77   8820.75     C
# 11          杭州       NaN  12603.36  11313.72  10050.21   9206.16     C
# 12          宁波       NaN   9842.10   8686.49   8003.61   7610.28     D
# 13          合肥       NaN   7213.45   6274.38   5660.27   5157.97     D
# 14          福州       NaN   7103.40   6197.64   5618.08   5169.16     D
# 15          厦门       NaN   4351.70   3784.27   3466.03   3273.58     D
# 16          南昌       NaN   5003.19   4354.99   4000.01   3667.96     D
# 17          济南       NaN   7201.96   6536.12   6100.23   5770.60     D
# 18          青岛       NaN  11037.28  10011.29   9300.07   8692.10     C
# 19          郑州       NaN   9130.20   8025.31   7311.52   6776.99     D
# 20          武汉       NaN  13410.34  11912.61  10905.60  10069.48     C
# 21          长沙       NaN  10535.51   9455.36   8510.13   7824.81     C
# 22          广州       NaN  21503.15  19547.44  18100.41  16706.87     B
# 23          深圳       NaN  22490.06  19492.60  17502.86  16001.82     B
# 24          南宁       NaN   4118.83   3703.39   3410.09   3148.30     D
# 25          海口       NaN   1390.58   1257.67   1161.96   1091.70     E
# 26          重庆  20363.19  19424.73  17740.59  15717.27  14262.60     C
# 27          成都       NaN  13889.39  12170.23  10801.16  10056.59     C
# 28          贵阳       NaN   3537.96   3157.70   2891.16   2497.27     E
# 29          昆明       NaN   4857.64   4300.08   3968.01   3712.99     D
# 30          拉萨       NaN    479.25    424.95    376.73    347.45     E
# 31          西安       NaN   7469.85   6257.18   5801.20   5492.64     D
# 32          兰州       NaN   2523.54   2264.23   2095.99   2000.94     E
# 33          西宁       NaN   1284.91   1248.17   1131.62   1065.78     E
# 34          银川       NaN   1803.26   1617.71   1493.86   1388.62     E
# 35        乌鲁木齐       NaN   2743.82   2458.98   2631.64   2461.47     E
# 36  数据来源：国家统计局       NaN       NaN       NaN       NaN       NaN   NaN

# %% [markdown]
# ### 将处理后的数据进行保存

# %%
df.to_excel('data/city2.xls')

# %% [markdown]
# ## 合并数据集
# ### &emsp;(1)append

# %%
df_n1 = df[df['2017年']>25000]
df_n2 = df[(20000<df['2017年'])&(df['2017年']<=25000)]

# %%
df_n2.append(df_n1)
# Out:
#     地区     2018年     2017年     2016年     2015年     2014年 GDP等级
# 22  广州       NaN  21503.15  19547.44  18100.41  16706.87     B
# 23  深圳       NaN  22490.06  19492.60  17502.86  16001.82     B
# 0   北京  30319.98  28014.94  25669.13  23014.59  21330.83     B
# 9   上海  32679.87  30632.99  28178.65  25123.45  23567.70     A

# %% [markdown]
# ### &emsp;(2)merge<br/>
# pd.merge(left,right,how='inner',on=None,left_on=None,right_on=None,left_index=False,right_index=False,sort=True,suffixes=('_x','_y'),copy=True,indicator=False)
# - left:对象
# - right:另一个对象
# - on:要加入的列
# - left_on:从左边的综合使用作为键列
# - right_on:
# - left_index:
# - right_index:
# - how:
# - sort:综合通过联接键按字典顺序对结果进行排序，默认值为True
# - suffixes:
# - indicator:

# %%
df1 = df.loc[:5]
df1
# Out:
#      地区     2018年     2017年     2016年     2015年     2014年 GDP等级
# 0    北京  30319.98  28014.94  25669.13  23014.59  21330.83     B
# 1    天津  18809.64  18549.19  17885.39  16538.19  15726.93     C
# 2   石家庄       NaN   6460.88   5927.73   5440.60   5170.27     D
# 3    太原       NaN   3382.18   2955.60   2735.34   2531.09     E
# 4  呼和浩特       NaN   2743.72   3173.59   3090.52   2894.05     E
# 5    沈阳       NaN   5864.97   5460.01   7272.31   7098.71     D

# %%
df2 = df.loc[:5][['地区']]
df2['2013年'] = [20001,14387.23,4902.65,2354.89,2749.20,6803.42]
df2
# Out:
#      地区     2013年
# 0    北京  20001.00
# 1    天津  14387.23
# 2   石家庄   4902.65
# 3    太原   2354.89
# 4  呼和浩特   2749.20
# 5    沈阳   6803.42

# %% [markdown]
# #### 将df1和df2合并

# %%
df3 = pd.merge(df1,df2,how='inner',on='地区')
df3
# Out:
#      地区     2018年     2017年     2016年     2015年     2014年 GDP等级     2013年
# 0    北京  30319.98  28014.94  25669.13  23014.59  21330.83     B  20001.00
# 1    天津  18809.64  18549.19  17885.39  16538.19  15726.93     C  14387.23
# 2   石家庄       NaN   6460.88   5927.73   5440.60   5170.27     D   4902.65
# 3    太原       NaN   3382.18   2955.60   2735.34   2531.09     E   2354.89
# 4  呼和浩特       NaN   2743.72   3173.59   3090.52   2894.05     E   2749.20
# 5    沈阳       NaN   5864.97   5460.01   7272.31   7098.71     D   6803.42

# %% [markdown]
# ### &emsp;(3)concat
#    - 将多个数据集进行批量合并

# %%
df4 = df[:5]
df5 = df[10:15]
df6 = df[20:25]

# %%
df4
# Out:
#      地区     2018年     2017年     2016年     2015年     2014年 GDP等级
# 0    北京  30319.98  28014.94  25669.13  23014.59  21330.83     B
# 1    天津  18809.64  18549.19  17885.39  16538.19  15726.93     C
# 2   石家庄       NaN   6460.88   5927.73   5440.60   5170.27     D
# 3    太原       NaN   3382.18   2955.60   2735.34   2531.09     E
# 4  呼和浩特       NaN   2743.72   3173.59   3090.52   2894.05     E

# %%
df5
# Out:
#     地区  2018年     2017年     2016年     2015年    2014年 GDP等级
# 10  南京    NaN  11715.10  10503.02   9720.77  8820.75     C
# 11  杭州    NaN  12603.36  11313.72  10050.21  9206.16     C
# 12  宁波    NaN   9842.10   8686.49   8003.61  7610.28     D
# 13  合肥    NaN   7213.45   6274.38   5660.27  5157.97     D
# 14  福州    NaN   7103.40   6197.64   5618.08  5169.16     D

# %%
df6
# Out:
#     地区  2018年     2017年     2016年     2015年     2014年 GDP等级
# 20  武汉    NaN  13410.34  11912.61  10905.60  10069.48     C
# 21  长沙    NaN  10535.51   9455.36   8510.13   7824.81     C
# 22  广州    NaN  21503.15  19547.44  18100.41  16706.87     B
# 23  深圳    NaN  22490.06  19492.60  17502.86  16001.82     B
# 24  南宁    NaN   4118.83   3703.39   3410.09   3148.30     D

# %%
dff = pd.concat([df4,df5,df6],axis=0) #axis=0增加行数，axis=1:增加列数
dff
# Out:
#       地区     2018年     2017年     2016年     2015年     2014年 GDP等级
# 0     北京  30319.98  28014.94  25669.13  23014.59  21330.83     B
# 1     天津  18809.64  18549.19  17885.39  16538.19  15726.93     C
# 2    石家庄       NaN   6460.88   5927.73   5440.60   5170.27     D
# 3     太原       NaN   3382.18   2955.60   2735.34   2531.09     E
# 4   呼和浩特       NaN   2743.72   3173.59   3090.52   2894.05     E
# 10    南京       NaN  11715.10  10503.02   9720.77   8820.75     C
# 11    杭州       NaN  12603.36  11313.72  10050.21   9206.16     C
# 12    宁波       NaN   9842.10   8686.49   8003.61   7610.28     D
# 13    合肥       NaN   7213.45   6274.38   5660.27   5157.97     D
# 14    福州       NaN   7103.40   6197.64   5618.08   5169.16     D
# 20    武汉       NaN  13410.34  11912.61  10905.60  10069.48     C
# 21    长沙       NaN  10535.51   9455.36   8510.13   7824.81     C
# 22    广州       NaN  21503.15  19547.44  18100.41  16706.87     B
# 23    深圳       NaN  22490.06  19492.60  17502.86  16001.82     B
# 24    南宁       NaN   4118.83   3703.39   3410.09   3148.30     D
